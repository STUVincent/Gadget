# %%
# -*- coding: utf-8 -*-
"""
******* 文档说明 ******
查询指定文件夹下各文件、文件夹信息
"""
import os


#  把文件大小 xx B 转换成对应的最佳显示方式
def _size_h(size):
    if size >= 1024*1024*1024:
        return "{:.1f}GB".format(size/(1024*1024*1024))
    elif size >= 1024*1024:
        return "{:.1f}MB".format(size/(1024*1024))
    elif size >= 1024:
        return "{:.1f}KB".format(size/1024)
    else:
        return "{:.0f}B".format(size)


# 查询文件夹中有多少个文件并计算总大小
def _get_folder_size(folder_path):
    f_size = 0
    f_num = 0
    for root_i, _, files_i in os.walk(folder_path, topdown=True):
        for file_ii in files_i:
            f_size += os.path.getsize(os.path.join(root_i, file_ii))
            f_num += 1
    return f_num, f_size


# 打印指定路径下的 各文件信息   http://192.168.0.100:8888/tree/Desktop/FaceNetDemo
def print_folder_info(path='.', display_layer=3, url="http://192.168.0.100:8888/"):
    path = os.path.abspath(path.strip())

    print('Search Path:  【{}】  DefaultURL: {}'.format(path, url))

    root = []  # 根目录
    dirs = []  # 文件夹名称
    files = []  # 文件名称
    for root_i, dirs_i, files_i in os.walk(path, topdown=True):
        root.append(root_i)
        dirs.append(dirs_i)
        files.append(files_i)

    # 文件夹大小
    folder_size = 0
    # 文件总数量
    files_num = 0

    for i, root_i in enumerate(root):
        # 当前层次级别
        diff_layer = len(root_i.split(os.sep)) - len(path.split(os.sep)) + 1

        # 非末层文件夹
        if diff_layer < display_layer:
            print(u'{}└-- {}'.format('    ' * (diff_layer - 1), root_i))
            print(u'{} {}'.format('    ' * (diff_layer - 1), url + 'tree/' + '/'.join(root_i.split('/')[2:])))

        # 末层文件夹
        elif diff_layer == display_layer:
            f_num, f_size = _get_folder_size(root_i)
            folder_size += f_size
            files_num += f_num
            print(u'{}└-- {}   【FileNum:{}  Size:{}】'.
                  format('    ' * (diff_layer - 1), root_i, f_num, _size_h(f_size)))
            print(u'{} {}'.format('    ' * (diff_layer - 1), url + 'tree/' + '/'.join(root_i.split('/')[2:])))

        # 文件信息
        if diff_layer < display_layer:
            files_size = 0
            for file_i in files[i]:
                files_size += os.path.getsize(os.path.join(root_i, file_i))
            folder_size += files_size
            files_num += len(files[i])

            if len(files[i]) > 1:
                print("{} ps: {}  ... 【FileNum:{}  Size:{}】".
                      format('    ' * diff_layer, "  ".join(sorted(files[i])[:1]), len(files[i]), _size_h(files_size)))
            elif len(files[i]) > 0:
                print("{} ps: {}      【FileNum:{}  Size:{}】".
                      format('    ' * diff_layer, "  ".join(sorted(files[i])[:1]), len(files[i]), _size_h(files_size)))

    print('\n{}  FileNum:【{}】 Folder Size:【{}】'.format(path, files_num, _size_h(folder_size)))


# 打印指定路径下的 各文件路径   http://192.168.0.100:8888/tree/Desktop/FaceNetDemo
def print_file_info(path='.', display_num=100, url="http://192.168.0.100:8888/"):
    path = os.path.abspath(path.strip())
    num = 0
    for file_i in sorted(os.listdir(path)):
        if os.path.isfile(os.path.abspath(os.path.join(path, file_i))):
            print("File:{}   Size:{}".format(file_i, _size_h(os.path.getsize(os.path.join(path, file_i)))))

            if file_i.endswith((".jpg", ".png", ".JPG", ".PNG")):
                print(url + 'view/' + '/'.join(os.path.abspath(os.path.join(path, file_i)).split('/')[2:]))
            else:
                print(url + 'edit/' + '/'.join(os.path.abspath(os.path.join(path, file_i)).split('/')[2:]))

            if num >= display_num:
                break
            num += 1

# if __name__ == '__main__':
#     # print_folder_info(r"D:\Desktop\Gadget")
#     print_file_info(r"D:\Desktop\Gadget")

# %%
print_folder_info('/notebooks/Desktop/LP_project ', display_layer=3, url="http://192.168.0.100:8888/")
# Out:
# Search Path:  【/notebooks/Desktop/LP_project】  DefaultURL: http://192.168.0.100:8888/
# └-- /notebooks/Desktop/LP_project
#  http://192.168.0.100:8888/tree/Desktop/LP_project
#      ps: Get_LPTraindata_Label.py  ... 【FileNum:11  Size:5.2GB】
#     └-- /notebooks/Desktop/LP_project/model
#      http://192.168.0.100:8888/tree/Desktop/LP_project/model
#          ps: lp-v1.py      【FileNum:1  Size:3.5KB】
#         └-- /notebooks/Desktop/LP_project/model/__pycache__   【FileNum:1  Size:2.9KB】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/model/__pycache__
#     └-- /notebooks/Desktop/LP_project/.ipynb_checkpoints
#      http://192.168.0.100:8888/tree/Desktop/LP_project/.ipynb_checkpoints
#          ps: Untitled-checkpoint.ipynb      【FileNum:1  Size:72B】
#     └-- /notebooks/Desktop/LP_project/_result
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_result
#          ps: LP_model.lp-v1_20190324-225429.h5_reulst.csv  ... 【FileNum:4  Size:45.1MB】
#         └-- /notebooks/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5   【FileNum:176474  Size:2.2GB】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5
#         └-- /notebooks/Desktop/LP_project/_result/.ipynb_checkpoints   【FileNum:0  Size:0B】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_result/.ipynb_checkpoints
#         └-- /notebooks/Desktop/LP_project/_result/LP_model.lp-v1_20190325-035053.h5   【FileNum:176474  Size:2.2GB】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_result/LP_model.lp-v1_20190325-035053.h5
#         └-- /notebooks/Desktop/LP_project/_result/LP_model.lp-v1_20190325-022101.h5   【FileNum:176474  Size:2.2GB】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_result/LP_model.lp-v1_20190325-022101.h5
#         └-- /notebooks/Desktop/LP_project/_result/LP_model.lp-v1_20190324-225429.h5   【FileNum:182560  Size:2.3GB】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_result/LP_model.lp-v1_20190324-225429.h5
#     └-- /notebooks/Desktop/LP_project/_tensorboard_log
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_tensorboard_log
#          ps: events.out.tfevents.1553439275.ae0c82bbac69  ... 【FileNum:5  Size:42.6MB】
#     └-- /notebooks/Desktop/LP_project/_DockerLog
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_DockerLog
#          ps: LP_Train_20190324162350.log  ... 【FileNum:8  Size:25.8MB】
#         └-- /notebooks/Desktop/LP_project/_DockerLog/.ipynb_checkpoints   【FileNum:0  Size:0B】
#          http://192.168.0.100:8888/tree/Desktop/LP_project/_DockerLog/.ipynb_checkpoints
#     └-- /notebooks/Desktop/LP_project/_log
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_log
#          ps: LP_model.lp-v1_20190324-225429.log  ... 【FileNum:5  Size:28.3KB】
#     └-- /notebooks/Desktop/LP_project/_model
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_model
#          ps: LP_model.lp-v1_20190324-225429.h5  ... 【FileNum:4  Size:42.6MB】
#     └-- /notebooks/Desktop/LP_project/_checkpoints
#      http://192.168.0.100:8888/tree/Desktop/LP_project/_checkpoints
#          ps: weights.h5      【FileNum:1  Size:10.7MB】
#
# /notebooks/Desktop/LP_project  FileNum:【712023】 Folder Size:【14.1GB】

# %%
print_file_info(' /notebooks/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5', display_num=20, url="http://192.168.0.100:8888/")
# Out:
# File:FalseAN_ccpd_base_皖AT772C-皖AT7720.jpg   Size:7.5KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseAN_ccpd_base_皖AT772C-皖AT7720.jpg
# File:FalseAN_ccpd_challenge_皖AD9328-皖AD9326.jpg   Size:23.1KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseAN_ccpd_challenge_皖AD9328-皖AD9326.jpg
# File:FalseCom_ccpd_base_云A005HL-A005HL.jpg   Size:9.8KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云A005HL-A005HL.jpg
# File:FalseCom_ccpd_base_云A2J6G2-A2J6G2.jpg   Size:14.4KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云A2J6G2-A2J6G2.jpg
# File:FalseCom_ccpd_base_云A552FV-A552FV.jpg   Size:13.3KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云A552FV-A552FV.jpg
# File:FalseCom_ccpd_base_云AFQ958-AFQ958.jpg   Size:12.0KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云AFQ958-AFQ958.jpg
# File:FalseCom_ccpd_base_云AH905Y-AH905Y.jpg   Size:9.0KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云AH905Y-AH905Y.jpg
# File:FalseCom_ccpd_base_云AZ7V17-AZ7V17.jpg   Size:12.5KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云AZ7V17-AZ7V17.jpg
# File:FalseCom_ccpd_base_云C3B685-C3B685.jpg   Size:12.5KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云C3B685-C3B685.jpg
# File:FalseCom_ccpd_base_云CV2030-CV2030.jpg   Size:12.0KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云CV2030-CV2030.jpg
# File:FalseCom_ccpd_base_云D87865-D87865.jpg   Size:6.9KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云D87865-D87865.jpg
# File:FalseCom_ccpd_base_云EY1121-EY1121.jpg   Size:24.3KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云EY1121-EY1121.jpg
# File:FalseCom_ccpd_base_云PNN111-PNN111.jpg   Size:2.9KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云PNN111-PNN111.jpg
# File:FalseCom_ccpd_base_云PV7812-PV7812.jpg   Size:6.9KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_云PV7812-PV7812.jpg
# File:FalseCom_ccpd_base_京A25071-A25071.jpg   Size:19.6KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京A25071-A25071.jpg
# File:FalseCom_ccpd_base_京A35061-A35061.jpg   Size:16.7KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京A35061-A35061.jpg
# File:FalseCom_ccpd_base_京AG8592-AG8592.jpg   Size:8.6KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京AG8592-AG8592.jpg
# File:FalseCom_ccpd_base_京CF5518-CF5518.jpg   Size:11.0KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京CF5518-CF5518.jpg
# File:FalseCom_ccpd_base_京EQ8988-EQ8988.jpg   Size:11.0KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京EQ8988-EQ8988.jpg
# File:FalseCom_ccpd_base_京ET0777-ET0777.jpg   Size:6.5KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京ET0777-ET0777.jpg
# File:FalseCom_ccpd_base_京FT4102-FT4102.jpg   Size:17.5KB
# http://192.168.0.100:8888/view/Desktop/LP_project/_result/LP_model.lp-v1_20190325-002630.h5/FalseCom_ccpd_base_京FT4102-FT4102.jpg
